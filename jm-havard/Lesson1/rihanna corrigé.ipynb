# %%
import requests
from bs4 import BeautifulSoup



def extractIntFromDOM(soup, classname):
  res_str = soup.find(class_=classname).text.replace(u'\xa0','').replace('vues','')
  res = int(res_str)
  return res

def extractLikeDislikeFromDOM(soup, classname, position):
  res_str = soup.find_all(class_=classname)[position].find(class_="yt-uix-button-content").text.replace(u'\xa0','')
  res = int(res_str)
  return res

def computeIndicatorForPage(url):
  result = requests.get(url)
  soup = BeautifulSoup(result.text, 'html.parser')
  number_of_views = extractIntFromDOM(soup,'watch-view-count')
  number_of_likes = extractLikeDislikeFromDOM(soup,'like-button-renderer-like-button', 0)
  number_of_dislikes = extractLikeDislikeFromDOM(soup,'like-button-renderer-dislike-button',1)
  indicator = 1000.* (number_of_likes - number_of_dislikes ) / number_of_views

  title = soup.title.text
  print ( '=====')
  print (title)
  print ("Likes", number_of_likes)
  print ("Dislikes", number_of_dislikes)
  print ("VIews", number_of_views)
  print ("Popularity", indicator)
  print ('=====')
  metrics = {}
  metrics['number_of_views'] = number_of_views
  metrics['number_of_likes'] = number_of_likes
  metrics['number_of_dislikes'] = number_of_dislikes
  metrics['indicator'] = indicator
  return  metrics
  metrics = {}
  metrics['number_of_views'] = number_of_views
  metrics['number_of_likes'] = number_of_likes
  metrics['number_of_dislikes'] = number_of_dislikes
  metrics['indicator'] = indicator
  return  metrics
#computeIndicatorForPage('https://www.youtube.com/watch?v=wfN4PVaOU5Q')


def getAllMetricsForArtist(artist):
  all_metrics = []
  MAX_PAGE = 1
  for page in range(1, MAX_PAGE + 1):
    all_videos_artist = requests.get('https://www.youtube.com/results?search_query=' + artist + '&page=' + str(page))
    soup_artist = BeautifulSoup(all_videos_artist.text, 'html.parser')
    list_video_artist = map(lambda x: x['href'] , soup_artist.find_all(class_="yt-uix-tile-link"))
    for link in list_video_artist:
      if 'watch' in link:
        metrics = computeIndicatorForPage('https://www.youtube.com' + link )
        all_metrics.append(metrics)
  return all_metrics

metrics_rihanna = getAllMetricsForArtist('rihanna')
metrics_beyonce = getAllMetricsForArtist('beyonce')
# Out:
# =====
# Calvin Harris - This Is What You Came For (Official Video) ft. Rihanna - YouTube
# Likes 3428132
# Dislikes 179390
# VIews 747206022
# Popularity 4.3478530744496595
# =====
# =====
# Chrissy Teigen Has Been Opening Rihanna's Mail - YouTube
# Likes 6605
# Dislikes 191
# VIews 372455
# Popularity 17.220872320146057
# =====
# =====
# 'Bates Motel' Star Can't Wait to Get Rihanna in Shower for Famous Scene - YouTube
# Likes 105
# Dislikes 10
# VIews 5435
# Popularity 17.47930082796688
# =====
# =====
# Rihanna - Sledgehammer (From The Motion Picture "Star Trek Beyond") - YouTube
# Likes 419013
# Dislikes 48584
# VIews 32055242
# Popularity 11.555957056883239
# =====
# =====
# Rihanna - Rude Boy - YouTube
# Likes 785061
# Dislikes 53623
# VIews 386812825
# Popularity 1.890935234631892
# =====
# =====
# Delia - Love On The Brain (Rihanna) (Live la Radio ZU) - YouTube
# Likes 581
# Dislikes 20
# VIews 22869
# Popularity 24.53102453102453
# =====
# =====
# Rihanna - What's My Name? ft. Drake - YouTube
# Likes 1307536
# Dislikes 72165
# VIews 577585027
# Popularity 2.1388556528491867
# =====
# =====
# Sia ft. Rihanna - Beautiful People - YouTube
# Likes 101576
# Dislikes 3938
# VIews 6377131
# Popularity 15.310646746946237
# =====
# =====
# Rihanna - What Now (Official) - YouTube
# Likes 954339
# Dislikes 47225
# VIews 196580238
# Popularity 4.614471979630018
# =====
# =====
# Beyoncé/Rihanna/Drake/Fugees Mashup Cover (@KeairaLaShae) - YouTube
# Likes 467
# Dislikes 3
# VIews 2450
# Popularity 189.3877551020408
# =====
# =====
# Rihanna - Don't Stop The Music - YouTube
# Likes 514497
# Dislikes 19326
# VIews 307703777
# Popularity 1.6092457649617997
# =====
# =====
# Rihanna ft. Akon - Emergency Room (Demo) - YouTube
# Likes 4156
# Dislikes 104
# VIews 217005
# Popularity 18.672380820718416
# =====
# =====
# Rihanna, Kanye West, Paul McCartney - FourFiveSeconds - YouTube
# Likes 1565577
# Dislikes 109582
# VIews 352765469
# Popularity 4.127373929561116
# =====
# =====
# Rihanna - American Oxygen - YouTube
# Likes 534061
# Dislikes 35248
# VIews 68547286
# Popularity 7.276918301331434
# =====
# =====
# Rihanna - Stay / Love On The Brain / Diamonds (Live From The 2016 MTV VMAs) - YouTube
# Likes 81829
# Dislikes 771
# VIews 2922771
# Popularity 27.733270926801996
# =====
# =====
# Rihanna - Russian Roulette - YouTube
# Likes 512293
# Dislikes 21779
# VIews 204197151
# Popularity 2.4021588822265203
# =====
# =====
# Rihanna - Only Girl (In The World) - YouTube
# Likes 1229010
# Dislikes 56951
# VIews 529101670
# Popularity 2.215186733392847
# =====
# =====
# Rihanna-Global Citizen Festival 2016 at Central Park NYC - YouTube
# Likes 1879
# Dislikes 21
# VIews 84684
# Popularity 21.940390156345945
# =====
# =====
# Beyoncé - Hold Up - YouTube
# Likes 582293
# Dislikes 38108
# VIews 31597588
# Popularity 17.222358871189787
# =====
# =====
# Beyoncé - Sorry - YouTube
# Likes 1204916
# Dislikes 98718
# VIews 134205660
# Popularity 8.242558473316253
# =====
# =====
# Beyoncé - 7/11 - YouTube
# Likes 1801968
# Dislikes 210135
# VIews 373553077
# Popularity 4.261330177719296
# =====
# =====
# Beyoncé - Run the World (Girls) - YouTube
# Likes 1206593
# Dislikes 155678
# VIews 329355840
# Popularity 3.190819388537334
# =====
# =====
# Beyoncé - Best Thing I Never Had - YouTube
# Likes 797753
# Dislikes 33871
# VIews 250457941
# Popularity 3.0499412274574276
# =====
# =====
# Beyoncé - Grown Woman - YouTube
# Likes 329229
# Dislikes 12940
# VIews 57685496
# Popularity 5.482990039645321
# =====
# =====
# Beyoncé - Irreplaceable - YouTube
# Likes 591712
# Dislikes 22018
# VIews 202684251
# Popularity 2.8107462577346474
# =====
# =====
# Beyoncé - If I Were A Boy - YouTube
# Likes 754245
# Dislikes 24002
# VIews 253961130
# Popularity 2.8754124696169057
# =====
# =====
# Beyoncé - Jealous - YouTube
# Likes 143043
# Dislikes 3694
# VIews 22331853
# Popularity 6.239921067006844
# =====
# =====
# Beyoncé - Pretty Hurts - YouTube
# Likes 1021955
# Dislikes 34159
# VIews 154949594
# Popularity 6.374950553274764
# =====
# =====
# Beyonce dans tous ses états, sa transformation diabolique - YouTube
# Likes 2572
# Dislikes 1563
# VIews 1269868
# Popularity 0.7945707742852013
# =====
# =====
# Beyoncé, Shakira - Beautiful Liar - YouTube
# Likes 622121
# Dislikes 21184
# VIews 211357384
# Popularity 2.8432269014079017
# =====
# =====
# Beyoncé - Get Me Bodied (Timbaland Remix) ft. Voltio - YouTube
# Likes 64601
# Dislikes 2111
# VIews 21332676
# Popularity 2.92930900933385
# =====
# =====
# Beyoncé - Countdown - YouTube
# Likes 481376
# Dislikes 23136
# VIews 119158937
# Popularity 3.8456200729618795
# =====
# =====
# Beyonce's Top Bossiest Moments (WARNING: Beyonce GOES OFF!) - YouTube
# Likes 3378
# Dislikes 139
# VIews 168028
# Popularity 19.276549146570808
# =====
# =====
# Beyoncé - Upgrade U ft. Jay-Z - YouTube
# Likes 247867
# Dislikes 9070
# VIews 85632453
# Popularity 2.7886273443550658
# =====
# =====
# Beyoncé & Bruno Mars Crash the Pepsi Super Bowl 50 Halftime Show | NFL - YouTube
# Likes 49124
# Dislikes 1318
# VIews 6510675
# Popularity 7.342710241257627
# =====
# =====
# Beyoncé - Diva - YouTube
# Likes 376010
# Dislikes 15198
# VIews 134222809
# Popularity 2.6881571223859577
# =====
# =====
# Beyoncé - ***Flawless ft. Chimamanda Ngozi Adichie - YouTube
# Likes 228526
# Dislikes 7664
# VIews 37493842
# Popularity 5.890620651785965
# =====
