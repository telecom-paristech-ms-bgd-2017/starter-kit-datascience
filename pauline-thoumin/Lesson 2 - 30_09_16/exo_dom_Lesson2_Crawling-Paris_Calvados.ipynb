# %%
########### INFO : SEUL LE DERNIER BLOC EST A CORRIGER, le reste n'est que de la construction ! ############


##################################################################################################################
####   REMARQUE : en quoi c'est utile ? 
#
# Pour le travail de crawling que je vous ai demandé vous aurez besoin de connaitre les selecteurs css.  
#Voici une page qui présente ce que c'est , à lire absolument . 
#Notamment vous aurez besoin des selecteur nth-of-type.
#
##################################################################################################################


import requests
import numpy as np
from bs4 import BeautifulSoup

# Récupération des données sur 2013

# on donne l'url
url='http://alize2.finances.gouv.fr/communes/eneuro/detail.php?icom=056&dep=075&type=BPS&param=5&exercice=2013'
result = requests.get(url)
soup = BeautifulSoup(result.text, 'html.parser')

list = soup.find_all(class_='montantpetit G')
A_hab = list[1].text.replace('<td class="montantpetit G">','')
A_strate = list[2].text.replace('<td class="montantpetit G">','')


print 'A = Par hab :', A_hab
print 'A = Par strate :', A_strate
# Out:
# Par hab : 2 308
# Par strate : 2 308

# %%
##### Maintenant que j'ai le A, je peux faire la même chose avec le B, C et D

import requests
import numpy as np
from bs4 import BeautifulSoup

# Récupération des données sur 2013

# on donne l'url
url='http://alize2.finances.gouv.fr/communes/eneuro/detail.php?icom=056&dep=075&type=BPS&param=5&exercice=2013'

def recup(url) :
    tab={}
    result = requests.get(url)
    soup = BeautifulSoup(result.text, 'html.parser')

    list = soup.find_all(class_='montantpetit G')

    A_h =list[1].text.replace('<td class="montantpetit G">','').replace(u'\xa0','')
    A_hab=int(A_h.replace(" ",''))
    A_s = list[2].text.replace('<td class="montantpetit G">','').replace(u'\xa0','')
    A_strate=int(A_s.replace(" ",''))
    
    B_h = list[4].text.replace('<td class="montantpetit G">','').replace(u'\xa0','')
    B_hab=int(B_h.replace(" ",''))
    B_s = list[5].text.replace('<td class="montantpetit G">','').replace(u'\xa0','')
    B_strate=int(B_s.replace(" ",''))

    C_h = list[10].text.replace('<td class="montantpetit G">','').replace(u'\xa0','')
    C_hab=int(C_h.replace(" ",''))
    C_s = list[11].text.replace('<td class="montantpetit G">','').replace(u'\xa0','')
    C_strate=int(C_s.replace(" ",''))

    D_h = list[13].text.replace('<td class="montantpetit G">','').replace(u'\xa0','')
    D_hab=int(D_h.replace(" ",''))
    D_s = list[14].text.replace('<td class="montantpetit G">','').replace(u'\xa0','')
    D_strate=int(D_s.replace(" ",''))
    
    tab['A_hab']=A_hab
    tab['A_strate']=A_strate
    tab['B_hab']=B_hab
    tab['B_strate']=B_strate
    tab['C_hab']=C_hab
    tab['C_strate']=C_strate
    tab['D_hab']=D_hab
    tab['D_strate']=D_strate
    
    return tab

#for el in list : 
#    print el, '\n'

#print 'A = Par hab :', A_hab
#print 'A = Par strate :', A_strate
#print 'B = Par hab :', B_hab
#print 'B = Par strate :', B_strate
#print 'C = Par hab :', C_hab
#print 'C = Par strate :', C_strate
#print 'D = Par hab :', D_hab
#print 'D = Par strate :', D_strate
print recup(url)
# Out:
# A = Par hab : 2 308
# A = Par strate : 2 308
# B = Par hab : 2 235
# B = Par strate : 2 235
# C = Par hab : 1 157
# C = Par strate : 1 157
# D = Par hab : 1 048
# D = Par strate : 1 048
# {'B_strate': 2235, 'A_strate': 2308, 'D_hab': 1048, 'C_strate': 1157, 'A_hab': 2308, 'C_hab': 1157, 'D_strate': 1048, 'B_hab': 2235}

# %%
### on en fait des fonctions et l'on boucle sur les années précédentes, avec un tableau de retour, et on retire les titres dans la liste (en tableau)
import requests
import numpy as np
from bs4 import BeautifulSoup

def recup(url) :
    tab=[]
    result = requests.get(url)
    soup = BeautifulSoup(result.text, 'html.parser')

    list = soup.find_all(class_='montantpetit G')

    A_h =list[1].text.replace('<td class="montantpetit G">','').replace(u'\xa0','')
    A_hab=int(A_h.replace(" ",''))
    A_s = list[2].text.replace('<td class="montantpetit G">','').replace(u'\xa0','')
    A_strate=int(A_s.replace(" ",''))
    
    B_h = list[4].text.replace('<td class="montantpetit G">','').replace(u'\xa0','')
    B_hab=int(B_h.replace(" ",''))
    B_s = list[5].text.replace('<td class="montantpetit G">','').replace(u'\xa0','')
    B_strate=int(B_s.replace(" ",''))

    C_h = list[10].text.replace('<td class="montantpetit G">','').replace(u'\xa0','')
    C_hab=int(C_h.replace(" ",''))
    C_s = list[11].text.replace('<td class="montantpetit G">','').replace(u'\xa0','')
    C_strate=int(C_s.replace(" ",''))

    D_h = list[13].text.replace('<td class="montantpetit G">','').replace(u'\xa0','')
    D_hab=int(D_h.replace(" ",''))
    D_s = list[14].text.replace('<td class="montantpetit G">','').replace(u'\xa0','')
    D_strate=int(D_s.replace(" ",''))
    
    tab.append(A_hab)
    tab.append(A_strate)
    tab.append(B_hab)
    tab.append(B_strate)
    tab.append(C_hab)
    tab.append(C_strate)
    tab.append(D_hab)
    tab.append(D_strate)
    
    return tab

### Méthode principale ####

#for i in range (2010, 2014): 
#    annee = i
#    url='http://alize2.finances.gouv.fr/communes/eneuro/detail.php?icom=056&dep=075&type=BPS&param=5&exercice='+str(annee)
#    print annee
#    print recup(url)
    
### On va créer un tableau de tableau 

tab_final = [['ville', 'annee', 'A_hab', 'A_strate', 'B_hab', 'B_strate', 'C_hab', 'C_strate', 'D_hab', 'D_strate']]
for i in range (2010, 2014):
    tab = []
    tab.append('Paris')
    tab.append(annee)
    annee = i
    url='http://alize2.finances.gouv.fr/communes/eneuro/detail.php?icom=056&dep=075&type=BPS&param=5&exercice='+str(annee)
    tab.append(recup(url))
    tab_final.append(tab)
# print tab_final

### affichage final : 

for el in tab_final:
    print el, '\n'
# Out:
# ['ville', 'annee', 'A_hab', 'A_strate', 'B_hab', 'B_strate', 'C_hab', 'C_strate', 'D_hab', 'D_strate']
#
# ['Paris', 2013, [2449, 2449, 2241, 2241, 1119, 1119, 1265, 1265]]
#
# ['Paris', 2010, [2546, 2546, 2327, 2327, 1264, 1264, 1268, 1268]]
#
# ['Paris', 2011, [2311, 2311, 2135, 2135, 1085, 1085, 1058, 1058]]
#
# ['Paris', 2012, [2308, 2308, 2235, 2235, 1157, 1157, 1048, 1048]]

# %%
###### Maintenant on va essayer de l'enregistrer sous format txt --- ECHEC

#mon_fichier = open("Paris.txt", "w") 

#mon_fichier.write()

#mon_fichier.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-06e6dbf7f381> in <module>()
#       3 mon_fichier = open("Paris.txt", "w")
#       4
# ----> 5 mon_fichier.write(recup(url))
#       6
#       7 mon_fichier.close()
#
# TypeError: expected a string or other character buffer object

# %%
##### On essaie de rajouter Caen, maintenant

### on en fait des fonctions et l'on boucle sur les années précédentes, avec un tableau de retour, et on retire les titres dans la liste (en tableau)
import requests
import numpy as np
from bs4 import BeautifulSoup

def recup(url) :
    tab=[]
    result = requests.get(url)
    soup = BeautifulSoup(result.text, 'html.parser')

    list = soup.find_all(class_='montantpetit G')

    A_h =list[1].text.replace('<td class="montantpetit G">','').replace(u'\xa0','')
    A_hab=int(A_h.replace(" ",''))
    A_s = list[2].text.replace('<td class="montantpetit G">','').replace(u'\xa0','')
    A_strate=int(A_s.replace(" ",''))
    
    B_h = list[4].text.replace('<td class="montantpetit G">','').replace(u'\xa0','')
    B_hab=int(B_h.replace(" ",''))
    B_s = list[5].text.replace('<td class="montantpetit G">','').replace(u'\xa0','')
    B_strate=int(B_s.replace(" ",''))

    C_h = list[10].text.replace('<td class="montantpetit G">','').replace(u'\xa0','')
    C_hab=int(C_h.replace(" ",''))
    C_s = list[11].text.replace('<td class="montantpetit G">','').replace(u'\xa0','')
    C_strate=int(C_s.replace(" ",''))

    D_h = list[13].text.replace('<td class="montantpetit G">','').replace(u'\xa0','')
    D_hab=int(D_h.replace(" ",''))
    D_s = list[14].text.replace('<td class="montantpetit G">','').replace(u'\xa0','')
    D_strate=int(D_s.replace(" ",''))
    
    tab.append(A_hab)
    tab.append(A_strate)
    tab.append(B_hab)
    tab.append(B_strate)
    tab.append(C_hab)
    tab.append(C_strate)
    tab.append(D_hab)
    tab.append(D_strate)
    
    return tab

### Caen : numero de commune : 118 numéro de departmt : 14 (merci Wikipedia)
### Paris : numero de commune : 056 numero de departmt : 75

tab_final = [['ville', 'annee', 'A_hab', 'A_strate', 'B_hab', 'B_strate', 'C_hab', 'C_strate', 'D_hab', 'D_strate']]
for i in range (2010, 2014):
    tab = []
    tab.append('056')
    tab.append('Paris')
    tab.append(annee)
    annee = i
    url='http://alize2.finances.gouv.fr/communes/eneuro/detail.php?icom=056&dep=075&type=BPS&param=5&exercice='+str(annee)
    tab.append(recup(url))
    tab_final.append(tab)
    
for i in range (2010, 2014):
    tab = []
    tab.append('Caen')
    tab.append(annee)
    annee = i
    url='http://alize2.finances.gouv.fr/communes/eneuro/detail.php?icom=118&dep=014&type=BPS&param=5&exercice='+str(annee)
    tab.append(recup(url))
    tab_final.append(tab)
# print tab_final

### affichage final : 

for el in tab_final:
    print el, '\n'
# Out:
# ['ville', 'annee', 'A_hab', 'A_strate', 'B_hab', 'B_strate', 'C_hab', 'C_strate', 'D_hab', 'D_strate']
#
# ['Paris', 2013, [2449, 2449, 2241, 2241, 1119, 1119, 1265, 1265]]
#
# ['Paris', 2010, [2546, 2546, 2327, 2327, 1264, 1264, 1268, 1268]]
#
# ['Paris', 2011, [2311, 2311, 2135, 2135, 1085, 1085, 1058, 1058]]
#
# ['Paris', 2012, [2308, 2308, 2235, 2235, 1157, 1157, 1048, 1048]]
#
# ['Caen', 2013, [1356, 1355, 1180, 1235, 436, 531, 401, 521]]
#
# ['Caen', 2010, [1330, 1383, 1226, 1258, 451, 507, 434, 526]]
#
# ['Caen', 2011, [1353, 1419, 1204, 1296, 554, 583, 527, 583]]
#
# ['Caen', 2012, [1489, 1434, 1292, 1330, 562, 595, 571, 600]]

# %%
# PARIS & CAEN de 2010 à 2013 

import requests
import numpy as np
from bs4 import BeautifulSoup

def recup(url) :
    tab=[]
    result = requests.get(url)
    soup = BeautifulSoup(result.text, 'html.parser')

    list = soup.find_all(class_='montantpetit G')

    A_h =list[1].text.replace('<td class="montantpetit G">','').replace(u'\xa0','')
    A_hab=int(A_h.replace(" ",''))
    A_s = list[2].text.replace('<td class="montantpetit G">','').replace(u'\xa0','')
    A_strate=int(A_s.replace(" ",''))
    
    B_h = list[4].text.replace('<td class="montantpetit G">','').replace(u'\xa0','')
    B_hab=int(B_h.replace(" ",''))
    B_s = list[5].text.replace('<td class="montantpetit G">','').replace(u'\xa0','')
    B_strate=int(B_s.replace(" ",''))

    C_h = list[10].text.replace('<td class="montantpetit G">','').replace(u'\xa0','')
    C_hab=int(C_h.replace(" ",''))
    C_s = list[11].text.replace('<td class="montantpetit G">','').replace(u'\xa0','')
    C_strate=int(C_s.replace(" ",''))

    D_h = list[13].text.replace('<td class="montantpetit G">','').replace(u'\xa0','')
    D_hab=int(D_h.replace(" ",''))
    D_s = list[14].text.replace('<td class="montantpetit G">','').replace(u'\xa0','')
    D_strate=int(D_s.replace(" ",''))
    
    tab.append(A_hab)
    tab.append(A_strate)
    tab.append(B_hab)
    tab.append(B_strate)
    tab.append(C_hab)
    tab.append(C_strate)
    tab.append(D_hab)
    tab.append(D_strate)
    
    return tab

### Caen : numero de commune : 118 numéro de departmt : 14 (merci Wikipedia)
### Paris : numero de commune : 056 numero de departmt : 75
# autre méthode : boucler sur les deux villes avec leurs caractéristiques, rentrées dans des tableaux. Pour 2 villes, on peut le faire à la main
# ou faire un code qui recherche sur wikipedia le numero de ville et de departement pour l'intégrer dans l'url ?


tab_final = [['ville', 'annee', 'A_hab', 'A_strate', 'B_hab', 'B_strate', 'C_hab', 'C_strate', 'D_hab', 'D_strate']]
for i in range (2010, 2014):
    tab = []
    tab.append('Paris')
    tab.append(annee)
    annee = i
    url='http://alize2.finances.gouv.fr/communes/eneuro/detail.php?icom=056&dep=075&type=BPS&param=5&exercice='+str(annee)
    for i in range (8) : 
        tab.append(recup(url)[i])
    tab_final.append(tab)
    
for i in range (2010, 2014):
    tab = []
    tab.append('Caen')
    annee = i
    tab.append(annee)
    url='http://alize2.finances.gouv.fr/communes/eneuro/detail.php?icom=118&dep=014&type=BPS&param=5&exercice='+str(annee)
    for i in range (8) : 
        tab.append(recup(url)[i])
    tab_final.append(tab)

### affichage final : 

for el in tab_final:
    print el, '\n'

### Rq : il faut certainement l'extraire dans un fichier csv pour pouvoir l'étudier
# Out:
# ['ville', 'annee', 'A_hab', 'A_strate', 'B_hab', 'B_strate', 'C_hab', 'C_strate', 'D_hab', 'D_strate']
#
# ['Paris', 2010, 2449, 2449, 2241, 2241, 1119, 1119, 1265, 1265]
#
# ['Paris', 2010, 2546, 2546, 2327, 2327, 1264, 1264, 1268, 1268]
#
# ['Paris', 2011, 2311, 2311, 2135, 2135, 1085, 1085, 1058, 1058]
#
# ['Paris', 2012, 2308, 2308, 2235, 2235, 1157, 1157, 1048, 1048]
#
# ['Caen', 2010, 1356, 1355, 1180, 1235, 436, 531, 401, 521]
#
# ['Caen', 2011, 1330, 1383, 1226, 1258, 451, 507, 434, 526]
#
# ['Caen', 2012, 1353, 1419, 1204, 1296, 554, 583, 527, 583]
#
# ['Caen', 2013, 1489, 1434, 1292, 1330, 562, 595, 571, 600]

# %%
########################### CODE FINAL, PARIS & CALVADOS de 2010 à 2013 #############################################

import requests
import numpy as np
from bs4 import BeautifulSoup
import urllib

def recup(url) :
    tab=[]
    result = requests.get(url)
    soup = BeautifulSoup(result.text, 'html.parser')

    list = soup.find_all(class_='montantpetit G')

    A_h =list[1].text.replace('<td class="montantpetit G">','').replace(u'\xa0','')
    A_hab=int(A_h.replace(" ",''))
    A_s = list[2].text.replace('<td class="montantpetit G">','').replace(u'\xa0','')
    A_strate=int(A_s.replace(" ",''))
    
    B_h = list[4].text.replace('<td class="montantpetit G">','').replace(u'\xa0','')
    B_hab=int(B_h.replace(" ",''))
    B_s = list[5].text.replace('<td class="montantpetit G">','').replace(u'\xa0','')
    B_strate=int(B_s.replace(" ",''))

    C_h = list[10].text.replace('<td class="montantpetit G">','').replace(u'\xa0','')
    C_hab=int(C_h.replace(" ",''))
    C_s = list[11].text.replace('<td class="montantpetit G">','').replace(u'\xa0','')
    C_strate=int(C_s.replace(" ",''))

    D_h = list[13].text.replace('<td class="montantpetit G">','').replace(u'\xa0','')
    D_hab=int(D_h.replace(" ",''))
    D_s = list[14].text.replace('<td class="montantpetit G">','').replace(u'\xa0','')
    D_strate=int(D_s.replace(" ",''))
    
    tab.append(A_hab)
    tab.append(A_strate)
    tab.append(B_hab)
    tab.append(B_strate)
    tab.append(C_hab)
    tab.append(C_strate)
    tab.append(D_hab)
    tab.append(D_strate)
    
    return tab

### Caen : numero de commune : 118 numéro de departmt : 14 (merci Wikipedia)
### Paris : numero de commune : 056 numero de departmt : 75
# autre méthode : boucler sur les deux villes avec leurs caractéristiques, rentrées dans des tableaux. Pour 2 villes, on peut le faire à la main
# ou faire un code qui recherche sur wikipedia le numero de ville et de departement pour l'intégrer dans l'url ?

#def url_ok(url):
#    r = requests.head(url)
#    return r.status_code == 200
# on pourrait l'utiliser mais l'url marche meme quand la ville n'existe pas ! C'est une autre erreur sur la page

tab_final = [['ville', 'annee', 'A_hab', 'A_strate', 'B_hab', 'B_strate', 'C_hab', 'C_strate', 'D_hab', 'D_strate']]
for i in range (2010, 2014):
    tab = []
    tab.append('056')
    tab.append('Paris')
    annee = i
    tab.append(annee)
    url='http://alize2.finances.gouv.fr/communes/eneuro/detail.php?icom=056&dep=075&type=BPS&param=5&exercice='+str(annee)
    for i in range (8) : 
        tab.append(recup(url)[i])
    tab_final.append(tab)

for num_ville in range (1,770) : # 765
    num_ville_initial=num_ville
    if num_ville%20==0 :
        print num_ville
    if num_ville<10 :
        num_ville= str("00"+str(num_ville))
    if num_ville<100 : 
        num_ville = str("0"+ str(num_ville))
    #print "num de ville :", num_ville
    for i in range (2010, 2014):
        annee = i
        #print "annee", annee
        url='http://alize2.finances.gouv.fr/communes/eneuro/detail.php?icom='+str(num_ville)+'&dep=014&type=BPS&param=5&exercice='+str(annee)
        result = requests.get(url)
        soup = BeautifulSoup(result.text, 'html.parser')
        #print ("longueur", len(soup.find_all(class_='G')))
        
        if len(soup.find_all(class_='G')) != 0 : 
            
            liste = soup.find_all(class_='G')
            #print liste[0]
            
            nom_ville=str(liste[1].text.replace('<td align="center" class="G" colspan="2">','').replace('</td>', ''))
            tab = []
            tab.append(num_ville)
            tab.append(nom_ville)
            tab.append(annee)
            for i in range (8) : 
                tab.append(recup(url)[i])
            tab_final.append(tab)

### affichage final : 

#for el in tab_final:
#    print el, '\n'

from pandas import DataFrame
l0=[]
l1=[]
l2=[]
l3=[]
l4=[]
l5=[]
l6=[]
l7=[]
l8=[]
l9=[]
l10=[]
for i in range(1,len(tab_final)) : 
        l0.append(tab_final[i][0])
        l1.append(tab_final[i][1])
        l2.append(tab_final[i][2])
        l3.append(tab_final[i][3])
        l4.append(tab_final[i][4])
        l5.append(tab_final[i][5])
        l6.append(tab_final[i][6])
        l7.append(tab_final[i][7])
        l8.append(tab_final[i][8])
        l9.append(tab_final[i][9])
        l10.append(tab_final[i][10])
df=DataFrame({'NumeroVille' : l0, 'Ville' : l1, 'Annee' : l2, 'A_hab': l3, 'A_strate' : l4,'B_hab': l5, 'B_strate' : l6,'C_hab': l7, 'C_strate' : l8,'D_hab': l9, 'D_strate' : l10 })
print df

df.to_excel('Calvados-total.xlsx', sheet_name='Calvados', index=False)


#lance a 8h38
# Out:
# 20
# 40
# 60
# 80
# 100
# 120
# 140
# 160
# 180
# 200
# 220
# 240
# 260
# 280
# 300
# 320
# 340
# 360
# 380
# 400
# 420
# 440
# 460
# 480
# 500
# 520
# 540
# 560
# 580
# 600
# 620
# 640
# 660
# 680
# 700
# 720
# 740
# 760
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-99-2d785811a471> in <module>()
#     124         l6.append(tab_final[i][6])
#     125         l7.append(tab_final[i][7])
# --> 126         l8.append(tab_final[i][8])
#     127         l9.append(tab_final[i][9])
#     128         l10.append(tab_final[i][10])
#
# IndexError: list index out of range

# %%
# Out:
#       A_hab  A_strate  Annee  B_hab  B_strate  C_hab  C_strate  D_hab  \
# 0       480       787   2010    446       620    233       443    369
# 1       481       813   2011    435       627    266       431    170
# 2       501       834   2012    452       648    193       439    135
# 3       505       850   2013    466       673    167       446    173
# 4       475       797   2010    412       621    240       502     89
# 5       584       833   2011    438       636    130       517    250
# 6       441       857   2012    259       639    117       495     38
# 7       375       841   2013    279       656     87       503    141
# 8       867       797   2010    965       621   1504       502    725
# 9       432       833   2011    283       636     17       517     35
# 10      427       857   2012    317       639    405       495    482
# 11      415       841   2013    333       656    128       503    164
# 12      393       809   2010    346       614     93       542    103
# 13      395       854   2011    302       624     87       519    151
# 14      374       872   2012    278       633     15       496    100
# 15      337       882   2013    278       656    125       532     94
# 16      962       787   2010    816       620    869       443     57
# 17      647       813   2011    522       627    117       431    379
# 18      784       834   2012    629       648    260       439    217
# 19      650       850   2013    517       673     49       446    124
# 20      561       787   2010    560       620    269       443    186
# 21      574       813   2011    529       627     29       431     75
# 22      593       834   2012    536       648     63       439     90
# 23      628       850   2013    540       673     92       446     40
# 24      480       797   2010    503       621     19       502     51
# 25      404       833   2011    338       636      8       517     17
# 26      546       857   2012    401       639     15       495     72
# 27      466       841   2013    416       656    148       503    563
# 28      579       724   2010    404       556    331       428    348
# 29      599       751   2011    415       560    464       414    139
# ...     ...       ...    ...    ...       ...    ...       ...    ...
# 2794    500       780   2012    366       579    368       443    191
# 2795    522       781   2013    326       600    684       444    186
# 2796    329       718   2010    292       574    330       400    496
# 2797    383       741   2011    295       581    118       392    152
# 2798    380       749   2012    290       588    106       396     54
# 2799    374       758   2013    311       611    167       404    143
# 2800    423       681   2010    397       547     28       412     43
# 2801    459       705   2011    408       548    229       396    260
# 2802    457       717   2012    413       558     72       393     69
# 2803    457       717   2013    431       570     81       397    101
# 2804    412       718   2010    338       574     27       400    190
# 2805    456       741   2011    329       581     64       392    107
# 2806    420       749   2012    345       588    227       396    261
# 2807    468       758   2013    351       611    478       404    345
# 2808    585       787   2010    490       620    190       443    270
# 2809    430       813   2011    455       627     27       431     63
# 2810    410       834   2012    395       648     10       439     64
# 2811    411       850   2013    383       673    269       446    176
# 2812   1401      1296   2010   1202      1151    520       480    537
# 2813   1430      1327   2011   1224      1193    422       457    421
# 2814   1432      1353   2012   1280      1223    339       519    442
# 2815   1500      1381   2013   1358      1244    618       552    517
# 2816    346       809   2010    303       614     54       542     66
# 2817    481       854   2011    413       624     29       519    126
# 2818    478       872   2012    357       633    134       496     90
# 2819    466       882   2013    432       656    214       532    206
# 2820    668       718   2010    555       574    182       400    131
# 2821    682       741   2011    622       581    376       392    395
# 2822    832       749   2012    701       588     93       396    180
# 2823    623       758   2013    520       611    152       404    124
#
#       D_strate NumeroVille                 Ville
# 0          433         001                 ABLON
# 1          430         001                 ABLON
# 2          422         001                 ABLON
# 3          461         001                 ABLON
# 4          493         002            ACQUEVILLE
# 5          507         002            ACQUEVILLE
# 6          502         002            ACQUEVILLE
# 7          522         002            ACQUEVILLE
# 8          493         003                   AGY
# 9          507         003                   AGY
# 10         502         003                   AGY
# 11         522         003                   AGY
# 12         516         004           AIGNERVILLE
# 13         514         004           AIGNERVILLE
# 14         497         004           AIGNERVILLE
# 15         550         004           AIGNERVILLE
# 16         433         005                 AIRAN
# 17         430         005                 AIRAN
# 18         422         005                 AIRAN
# 19         461         005                 AIRAN
# 20         433         006        AMAYE-SUR-ORNE
# 21         430         006        AMAYE-SUR-ORNE
# 22         422         006        AMAYE-SUR-ORNE
# 23         461         006        AMAYE-SUR-ORNE
# 24         493         007     AMAYE-SUR-SEULLES
# 25         507         007     AMAYE-SUR-SEULLES
# 26         502         007     AMAYE-SUR-SEULLES
# 27         522         007     AMAYE-SUR-SEULLES
# 28         413         008                AMBLIE
# 29         419         008                AMBLIE
# ...        ...         ...                   ...
# 2794       436         757       VILLIERS-LE-SEC
# 2795       452         757       VILLIERS-LE-SEC
# 2796       393         758  VILLONS-LES-BUISSONS
# 2797       392         758  VILLONS-LES-BUISSONS
# 2798       390         758  VILLONS-LES-BUISSONS
# 2799       417         758  VILLONS-LES-BUISSONS
# 2800       395         759     VILLY-LEZ-FALAISE
# 2801       397         759     VILLY-LEZ-FALAISE
# 2802       394         759     VILLY-LEZ-FALAISE
# 2803       407         759     VILLY-LEZ-FALAISE
# 2804       393         760          VILLY-BOCAGE
# 2805       392         760          VILLY-BOCAGE
# 2806       390         760          VILLY-BOCAGE
# 2807       417         760          VILLY-BOCAGE
# 2808       433         761                VIMONT
# 2809       430         761                VIMONT
# 2810       422         761                VIMONT
# 2811       461         761                VIMONT
# 2812       491         762                  VIRE
# 2813       458         762                  VIRE
# 2814       487         762                  VIRE
# 2815       575         762                  VIRE
# 2816       516         763               VOUILLY
# 2817       514         763               VOUILLY
# 2818       497         763               VOUILLY
# 2819       550         763               VOUILLY
# 2820       393         764         PONT-D'OUILLY
# 2821       392         764         PONT-D'OUILLY
# 2822       390         764         PONT-D'OUILLY
# 2823       417         764         PONT-D'OUILLY
#
# [2824 rows x 11 columns]

# %%
print tab_final # ok
# Out:
# [['ville', 'annee', 'A_hab', 'A_strate', 'B_hab', 'B_strate', 'C_hab', 'C_strate', 'D_hab', 'D_strate'], ['Paris', 2010, 2449, 2449, 2241, 2241, 1119, 1119], ['Paris', 2011, 2546, 2546, 2327, 2327, 1264, 1264], ['Paris', 2012, 2311, 2311, 2135, 2135, 1085, 1085], ['Paris', 2013, 2308, 2308, 2235, 2235, 1157, 1157], ['001', 'ABLON', 2010, 480, 787, 446, 620, 233, 443, 369, 433], ['001', 'ABLON', 2011, 481, 813, 435, 627, 266, 431, 170, 430], ['001', 'ABLON', 2012, 501, 834, 452, 648, 193, 439, 135, 422], ['001', 'ABLON', 2013, 505, 850, 466, 673, 167, 446, 173, 461], ['002', 'ACQUEVILLE', 2010, 475, 797, 412, 621, 240, 502, 89, 493], ['002', 'ACQUEVILLE', 2011, 584, 833, 438, 636, 130, 517, 250, 507], ['002', 'ACQUEVILLE', 2012, 441, 857, 259, 639, 117, 495, 38, 502], ['002', 'ACQUEVILLE', 2013, 375, 841, 279, 656, 87, 503, 141, 522], ['003', 'AGY', 2010, 867, 797, 965, 621, 1504, 502, 725, 493], ['003', 'AGY', 2011, 432, 833, 283, 636, 17, 517, 35, 507], ['003', 'AGY', 2012, 427, 857, 317, 639, 405, 495, 482, 502], ['003', 'AGY', 2013, 415, 841, 333, 656, 128, 503, 164, 522], ['004', 'AIGNERVILLE', 2010, 393, 809, 346, 614, 93, 542, 103, 516], ['004', 'AIGNERVILLE', 2011, 395, 854, 302, 624, 87, 519, 151, 514], ['004', 'AIGNERVILLE', 2012, 374, 872, 278, 633, 15, 496, 100, 497], ['004', 'AIGNERVILLE', 2013, 337, 882, 278, 656, 125, 532, 94, 550], ['005', 'AIRAN', 2010, 962, 787, 816, 620, 869, 443, 57, 433], ['005', 'AIRAN', 2011, 647, 813, 522, 627, 117, 431, 379, 430], ['005', 'AIRAN', 2012, 784, 834, 629, 648, 260, 439, 217, 422], ['005', 'AIRAN', 2013, 650, 850, 517, 673, 49, 446, 124, 461], ['006', 'AMAYE-SUR-ORNE', 2010, 561, 787, 560, 620, 269, 443, 186, 433], ['006', 'AMAYE-SUR-ORNE', 2011, 574, 813, 529, 627, 29, 431, 75, 430], ['006', 'AMAYE-SUR-ORNE', 2012, 593, 834, 536, 648, 63, 439, 90, 422], ['006', 'AMAYE-SUR-ORNE', 2013, 628, 850, 540, 673, 92, 446, 40, 461], ['007', 'AMAYE-SUR-SEULLES', 2010, 480, 797, 503, 621, 19, 502, 51, 493], ['007', 'AMAYE-SUR-SEULLES', 2011, 404, 833, 338, 636, 8, 517, 17, 507], ['007', 'AMAYE-SUR-SEULLES', 2012, 546, 857, 401, 639, 15, 495, 72, 502], ['007', 'AMAYE-SUR-SEULLES', 2013, 466, 841, 416, 656, 148, 503, 563, 522], ['008', 'AMBLIE', 2010, 579, 724, 404, 556, 331, 428, 348, 413], ['008', 'AMBLIE', 2011, 599, 751, 415, 560, 464, 414, 139, 419], ['008', 'AMBLIE', 2012, 550, 780, 412, 579, 159, 443, 216, 436], ['008', 'AMBLIE', 2013, 590, 781, 504, 600, 11, 444, 315, 452], ['009', 'AMFREVILLE', 2010, 532, 718, 441, 574, 70, 400, 200, 393], ['009', 'AMFREVILLE', 2011, 567, 741, 507, 581, 382, 392, 322, 392], ['009', 'AMFREVILLE', 2012, 608, 749, 481, 588, 296, 396, 248, 390], ['009', 'AMFREVILLE', 2013, 636, 758, 548, 611, 261, 404, 196, 417], ['011', 'ANCTOVILLE', 2010, 448, 718, 310, 574, 157, 400, 203, 393], ['011', 'ANCTOVILLE', 2011, 438, 741, 322, 581, 99, 392, 174, 392], ['011', 'ANCTOVILLE', 2012, 448, 749, 325, 588, 238, 396, 241, 390], ['011', 'ANCTOVILLE', 2013, 530, 758, 409, 611, 363, 404, 380, 417], ['012', 'ANGERVILLE', 2010, 483, 809, 412, 614, 11, 542, 166, 516], ['012', 'ANGERVILLE', 2011, 648, 854, 354, 624, 124, 519, 225, 514], ['012', 'ANGERVILLE', 2012, 499, 872, 386, 633, 259, 496, 192, 497], ['012', 'ANGERVILLE', 2013, 597, 882, 374, 656, 118, 532, 80, 550], ['013', 'ANGOVILLE', 2010, 939, 797, 647, 621, 118, 502, 2, 493], ['013', 'ANGOVILLE', 2011, 825, 833, 598, 636, 0, 517, 22, 507], ['013', 'ANGOVILLE', 2012, 740, 857, 342, 639, 65, 495, 155, 502], ['013', 'ANGOVILLE', 2013, 806, 841, 448, 656, 82, 503, 18, 522], ['014', 'ANGUERNY', 2010, 342, 718, 278, 574, 87, 400, 106, 393], ['014', 'ANGUERNY', 2011, 390, 741, 286, 581, 94, 392, 78, 392], ['014', 'ANGUERNY', 2012, 373, 749, 293, 588, 139, 396, 142, 390], ['014', 'ANGUERNY', 2013, 370, 758, 315, 611, 321, 404, 388, 417], ['015', 'ANISY', 2010, 427, 718, 318, 574, 73, 400, 157, 393], ['015', 'ANISY', 2011, 448, 741, 365, 581, 230, 392, 125, 392], ['015', 'ANISY', 2012, 440, 749, 357, 588, 414, 396, 73 ...
